# %% [markdown]
# <a href="https://colab.research.google.com/github/aksharagupta082007/epilepsy-detection-/blob/main/Copy_of_epilepsy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-11-2904419119.py in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/profile_report.py in <module>
# ...

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 27.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=e9971dfad31d27c31209ad4311100d13a6878da3e60709aaccbcf721247c0dc2
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
# ...

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-8-2904419119.py in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/profile_report.py in <module>
# ...

# %%
# !pip uninstall -y numba
# !pip install numba==0.56.4
# Out:
# Found existing installation: numba 0.60.0
# Uninstalling numba-0.60.0:
#   Successfully uninstalled numba-0.60.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 18.9 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-12-2904419119.py in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/profile_report.py in <module>
# ...

# %%
# !pip install numba==0.55.2
# !pip install pandas-profiling==3.1.0
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.52.0 Requires-Python >=3.6,<3.9; 0.52.0rc3 Requires-Python >=3.6,<3.9; 0.53.0 Requires-Python >=3.6,<3.10; 0.53.0rc1.post1 Requires-Python >=3.6,<3.10; 0.53.0rc2 Requires-Python >=3.6,<3.10; 0.53.0rc3 Requires-Python >=3.6,<3.10; 0.53.1 Requires-Python >=3.6,<3.10; 0.54.0 Requires-Python >=3.7,<3.10; 0.54.0rc2 Requires-Python >=3.7,<3.10; 0.54.0rc3 Requires-Python >=3.7,<3.10; 0.54.1 Requires-Python >=3.7,<3.10; 0.55.0 Requires-Python >=3.7,<3.11; 0.55.0rc1 Requires-Python >=3.7,<3.11; 0.55.1 Requires-Python >=3.7,<3.11; 0.55.2 Requires-Python >=3.7,<3.11
# ...

# %%
from pandas_profiling import ProfileReport

# Assuming df is your DataFrame
profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# /tmp/ipython-input-3-4187028202.py in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2
#       3 # Assuming df is your DataFrame
#       4 profile = ProfileReport(df)
#       5 profile.to_file("output.html")
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ...

# %%
# !pip install numba==0.55.2 pandas-profiling==3.1.0 --force-reinstall
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.52.0 Requires-Python >=3.6,<3.9; 0.52.0rc3 Requires-Python >=3.6,<3.9; 0.53.0 Requires-Python >=3.6,<3.10; 0.53.0rc1.post1 Requires-Python >=3.6,<3.10; 0.53.0rc2 Requires-Python >=3.6,<3.10; 0.53.0rc3 Requires-Python >=3.6,<3.10; 0.53.1 Requires-Python >=3.6,<3.10; 0.54.0 Requires-Python >=3.7,<3.10; 0.54.0rc2 Requires-Python >=3.7,<3.10; 0.54.0rc3 Requires-Python >=3.7,<3.10; 0.54.1 Requires-Python >=3.7,<3.10; 0.55.0 Requires-Python >=3.7,<3.11; 0.55.0rc1 Requires-Python >=3.7,<3.11; 0.55.1 Requires-Python >=3.7,<3.11; 0.55.2 Requires-Python >=3.7,<3.11
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd # Corrected import

# Assuming df is your DataFrame
# df = pd.read_csv('eeg_data.csv') # Example of loading df
df = pd.read_csv('/content/eeg_data.csv')
profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# 100%|██████████| 668/668 [00:08<00:00, 76.25it/s]

# %% [markdown]
# from ydata_profiling import ProfileReport
# import pandas as pd # Corrected import
#
# df = pd.read_csv('/content/eeg_data.csv')
#
# chunk_size = 10000
# num_chunks = len(df) // chunk_size + 1
#
# for i in range(num_chunks):
#     chunk_df = df.iloc[i*chunk_size : (i+1)*chunk_size]
#     profile = ProfileReport(chunk_df, title=f"Chunk {i+1} Report", minimal=True)
#     profile.to_file(f"chunk_{i+1}_profile.html")

# %%
from ydata_profiling import ProfileReport
import pandas as pd # Corrected import
df = pd.read_csv('/content/eeg_data.csv')
chunk_size = 10000
num_chunks = len(df) // chunk_size + 1

for i in range(num_chunks):
    chunk_df = df.iloc[i*chunk_size : (i+1)*chunk_size]
    profile = ProfileReport(chunk_df, title=f"Chunk {i+1} Report", minimal=True)
    profile.to_file(f"chunk_{i+1}_profile.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata_profiling import ProfileReport
import pandas as pd # Corrected import

df = pd.read_csv('/content/eeg_data.csv')

column_chunks = [df.columns[i:i+100] for i in range(0, len(df.columns), 100)]

for idx, cols in enumerate(column_chunks):
    chunk_df = df[cols]
    profile = ProfileReport(chunk_df, title=f"Column Chunk {idx+1} Report", minimal=True)
    profile.to_file(f"column_chunk_{idx+1}.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4-2994724328.py in <cell line: 0>()
# ----> 1 from ydata_profiling import ProfileReport
#       2 import pandas as pd # Corrected import
#       3
#       4 df = pd.read_csv('/content/eeg_data.csv')
#       5
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 4.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=a13c87f15f0231a045a3fc7ce5fdeba898f66a508f0755cc8e370125105e6a79
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd # Corrected import

df = pd.read_csv('/content/eeg_data.csv')

column_chunks = [df.columns[i:i+100] for i in range(0, len(df.columns), 100)]

for idx, cols in enumerate(column_chunks):
    chunk_df = df[cols]
    profile = ProfileReport(chunk_df, title=f"Column Chunk {idx+1} Report", minimal=True)
    profile.to_file(f"column_chunk_{idx+1}.html")
# Out:
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/eeg_data.csv')
duplicate_count = df.duplicated().sum()
print(f"Total duplicate rows: {duplicate_count}")
# Out:
# Total duplicate rows: 8

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# FP1_power_delta    0
# FP1_power_theta    0
# FP1_power_alpha    0
# FP1_power_beta     0
# FP1_power_gamma    0
#                   ..
# T6_STD_D3          0
# T6_STD_D4          0
# T6_STD_D5          0
# T6_STD_D6          0
# epileptic_         0
# Length: 668, dtype: int64

# %%
df.isnull().mean()*100
# Out:
# FP1_power_delta    0.0
# FP1_power_theta    0.0
# FP1_power_alpha    0.0
# FP1_power_beta     0.0
# FP1_power_gamma    0.0
#                   ...
# T6_STD_D3          0.0
# T6_STD_D4          0.0
# T6_STD_D5          0.0
# T6_STD_D6          0.0
# epileptic_         0.0
# Length: 668, dtype: float64

# %%
cols [var for var in df.columns if df[var].isnull().mean() > 0] cols
# Out:
#   File "/tmp/ipython-input-6-3075727403.py", line 1
#     cols [var for var in df.columns if df[var].isnull().mean() > 0] cols
#               ^
# SyntaxError: invalid syntax

# %%
# Get columns with >0% and <5% missing values
cols = [col for col in df.columns if 0 < df[col].isnull().mean() ]
print("Columns with <0% missing values:", cols)
# Out:
# Columns with <0% missing values: []

# %%
# Step 1: Get skewness of each numeric column
skewness = df.select_dtypes(include='number').skew()

# Step 2: Define thresholds
# You can adjust threshold: |skew| > 1 = skewed, <= 1 = not skewed
skewed_cols = skewness[abs(skewness) > 1].index.tolist()
non_skewed_cols = skewness[abs(skewness) <= 1].index.tolist()

# Optional: print count
print(f"Skewed columns: {len(skewed_cols)}")
print(f"Non-skewed columns: {len(non_skewed_cols)}")
import pandas as pd
from scipy.stats import zscore

def clean_outliers(df, skewed_cols, non_skewed_cols, z_thresh=3, iqr_thresh=1.5):
    df_cleaned = df.copy()

    # Handle skewed columns with IQR
    for col in skewed_cols:
        Q1 = df_cleaned[col].quantile(0.25)
        Q3 = df_cleaned[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - iqr_thresh * IQR
        upper_bound = Q3 + iqr_thresh * IQR
        df_cleaned = df_cleaned[(df_cleaned[col] >= lower_bound) & (df_cleaned[col] <= upper_bound)]

    # Handle non-skewed columns with Z-score
    for col in non_skewed_cols:
        z_scores = zscore(df_cleaned[col])
        df_cleaned = df_cleaned[abs(z_scores) < z_thresh]

    return df_cleaned
df_cleaned = clean_outliers(df, skewed_cols, non_skewed_cols)
# Out:
# Skewed columns: 634
# Non-skewed columns: 34
